# %% [markdown]
# # Creating an algorithm

# %% [markdown]
# In this notebook, we are going to explain how to implement a new optimization algorithm using the metaheuristic-designer framework.
#
# For this example, we are going to implement a basic evolutionary strategy.

# %%
import metaheuristic_designer as mhd
import random

# %% [markdown]
# For simplicity, we will assume we are working with real coded vectors.
#
# We will also predefine the operators, but in real situations it might be wiser to let the user specify the user they want to use.
#
# To configure our evolution strategy, we will need to specify the number of parents and offpring in each generation.
# The operator will be a gaussian mutation, it will have a standard deviation associated which will be another parameter.
#
# To create the algorithm, we will make a class that inherits from ```Algorithm``` and will implement its methods.
#
# In this case we will implement the ```select_parents``` method that chooses the individuals to be chosen for mutation, the ```perturb``` method that will perform a mutation on the selected indivuals, the ```select_individuals``` that will choose the individuals that will remain for the next generation.
#
# Here, we will make extensive use of already implemented components, like ```ParentSelection```, ```SurvivorSelection```, ```Operator```, but you can provide your own implementation of those, which will be explained in different notebooks.

# %% [markdown]
# The ```Algorithm``` class has some attributes that must be used for the
# algorithm to work correctly.
#
# The algorithm will have a ```name```, if unspecified, a default name will be chosen. This is the name of the algorithm showed in logs.
#
# A population initialization module ```pop_init``` must be present to perform the initialization of the algorithm (an explanation will be present in its respective notebook). It will also specify the size of the initialized population.
#
# The algorithm has a list of individuals called ```population``` which holds. It is a standard python list with variable size.
#
# We also have a ```best``` attribute that holds the best individual in each generation.
#
# You can optionally store the parameters of the algorithm in a dictionary or an instance of ```ParamScheduler``` in the attribute ```params```. It is recomended to use the latter because it allows parameters to change over time. We will not worry about this in this example.
#
# All of these attributes are generated on the ```__init__``` method of the ```Algorithm``` class.

# %%
# ES algorithm class
class BasicES(mhd.Algorithm):

    # Class constructor
    def __init__(self, pop_init, parent_size, offspring_size, sigma):
        self.parent_size = parent_size
        self.offspring_size = offspring_size

        # Create the mutation operator for use later
        self.mutate_op = mhd.Operators.OperatorReal("MutRand", {"method": "Gauss", "F": sigma, "N": 1})

        # Force pop_init to agree with the population size, this is not mandatory.
        pop_init.pop_size = parent_size

        # Create the parent selection module, select the best half of the parents
        self.parent_sel_op = mhd.SelectionMethods.ParentSelection("Best", {"amount": parent_size//2})

        # Create the parent selection module, select the best half of the parents
        self.surv_sel_op = mhd.SelectionMethods.SurvivorSelection("keepbest", {"amount": parent_size})

        super().__init__(pop_init, name="Basic ES")
    
    
    # This method receives the population from the previous generation
    # and some extra information (that we don't need here) and returns 
    # a list of selected individuals.
    def select_parents(self, population, **kwargs):
        return self.parent_sel_op(population)
    

    # This method receives the parents that we are going to mutate,
    # the objective function class and some extra information that we 
    # are not going to use.
    def perturb(self, parent_list, objfunc, **kwargs):
        offspring = []

        # Iterate until the list of individuals has the 
        # size we want.
        while len(offspring) < self.offspring_size:

            # Choose an individual from the parent list.
            indiv = random.choice(parent_list)

            # Apply the operator.
            new_indiv = self.mutate_op(indiv, parent_list, objfunc, self.best, self.pop_init)

            # Repair the solution to keep the vector within the bounds
            # of the problem.
            new_indiv.genotype = objfunc.repair_solution(new_indiv.genotype)

            # Add the individual to the offspring list.
            offspring.append(new_indiv)
        
        # Update the best solution
        current_best = max(offspring, key=lambda x: x.fitness)
        if self.best.fitness < current_best.fitness:
            self.best = current_best
        
        return offspring


    # This method selects the individuals that will be chosen for the next 
    # generation, it gets the original population along with the newly 
    # generated individuals.
    def select_individuals(self, prev_population, offspring, **kwargs):
        return self.surv_sel_op(prev_population, offspring)

# %% [markdown]
# To begin with the optimization we need one more component, the ```SearchMethod```. This is mostly the same for all algorithms, so it is recomended that you use the already implemented ```GeneralSearch``` class for this purpose unless you REALLY need something different. If this is the case, you have a ```Search``` base class available that you can inherit from.
#
# We will be using one of the benchmark functions already implemented in this framework that consist on adding the square of the vector components.

# %%
# Define the parameters of the optimization process
params = {
    "stop_cond": "time_limit",
    "time_limit": 100.0,

    "verbose": True,
    "v_timer": 2
}

# Define the parameters of the algorithm
n_parents = 50
n_offspring = 250

# Define the objective function
objfunc = mhd.benchmarks.Sphere(3)

# Define a population initialization module
pop_init = mhd.Initializers.UniformVectorInitializer(objfunc.vecsize, objfunc.low_lim, objfunc.up_lim, pop_size=n_parents)

# Instanciate the newly created algorithm
algorithm = BasicES(pop_init, n_parents, n_offspring, 1e-3)

# Define a Search method
search = mhd.GeneralSearch(objfunc, algorithm, params)

# Optimize the objective function 
best_solution, best_fitness = search.optimize()
# Out:
# Initializing optimization of Sphere function using Basic ES
# -----------------------------------------------------------
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 0.0 s
# 	CPU time Spent:  0.0 s
# 	Generation: 0
# 	Best fitness: 827.5038884637643
# 	Evaluations of fitness: 50
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 2.0 s
# 	CPU time Spent:  2.0 s
# 	Generation: 492
# 	Best fitness: 790.8091371947005
# 	Evaluations of fitness: 123050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 4.0 s
# 	CPU time Spent:  4.0 s
# 	Generation: 997
# 	Best fitness: 753.1283594931193
# 	Evaluations of fitness: 249300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 6.01 s
# 	CPU time Spent:  6.01 s
# 	Generation: 1499
# 	Best fitness: 717.2610364062208
# 	Evaluations of fitness: 374800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 8.01 s
# 	CPU time Spent:  8.01 s
# 	Generation: 2004
# 	Best fitness: 682.16252445809
# 	Evaluations of fitness: 501050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 10.01 s
# 	CPU time Spent:  10.01 s
# 	Generation: 2514
# 	Best fitness: 647.159564298729
# 	Evaluations of fitness: 628550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 12.01 s
# 	CPU time Spent:  12.01 s
# 	Generation: 3024
# 	Best fitness: 613.8062070044147
# 	Evaluations of fitness: 756050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 14.01 s
# 	CPU time Spent:  14.01 s
# 	Generation: 3533
# 	Best fitness: 581.295984430232
# 	Evaluations of fitness: 883300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 16.02 s
# 	CPU time Spent:  16.02 s
# 	Generation: 4040
# 	Best fitness: 549.975967986317
# 	Evaluations of fitness: 1010050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 18.02 s
# 	CPU time Spent:  18.02 s
# 	Generation: 4544
# 	Best fitness: 519.7488475069687
# 	Evaluations of fitness: 1136050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 20.02 s
# 	CPU time Spent:  20.02 s
# 	Generation: 5053
# 	Best fitness: 489.4759804187124
# 	Evaluations of fitness: 1263300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 22.02 s
# 	CPU time Spent:  22.02 s
# 	Generation: 5561
# 	Best fitness: 461.15908141051864
# 	Evaluations of fitness: 1390300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 24.02 s
# 	CPU time Spent:  24.02 s
# 	Generation: 6070
# 	Best fitness: 433.23062713107134
# 	Evaluations of fitness: 1517550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 26.03 s
# 	CPU time Spent:  26.03 s
# 	Generation: 6577
# 	Best fitness: 406.7783821291434
# 	Evaluations of fitness: 1644300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 28.03 s
# 	CPU time Spent:  28.03 s
# 	Generation: 7079
# 	Best fitness: 381.20138841211156
# 	Evaluations of fitness: 1769800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 30.03 s
# 	CPU time Spent:  30.03 s
# 	Generation: 7590
# 	Best fitness: 355.7998877091836
# 	Evaluations of fitness: 1897550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 32.03 s
# 	CPU time Spent:  32.03 s
# 	Generation: 8098
# 	Best fitness: 331.4152904861067
# 	Evaluations of fitness: 2024550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 34.04 s
# 	CPU time Spent:  34.04 s
# 	Generation: 8608
# 	Best fitness: 308.0992300175752
# 	Evaluations of fitness: 2152050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 36.04 s
# 	CPU time Spent:  36.04 s
# 	Generation: 9118
# 	Best fitness: 285.8917146512618
# 	Evaluations of fitness: 2279550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 38.04 s
# 	CPU time Spent:  38.04 s
# 	Generation: 9610
# 	Best fitness: 264.9495475010039
# 	Evaluations of fitness: 2402550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 40.04 s
# 	CPU time Spent:  40.04 s
# 	Generation: 10094
# 	Best fitness: 245.25565479907831
# 	Evaluations of fitness: 2523550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 42.05 s
# 	CPU time Spent:  42.05 s
# 	Generation: 10598
# 	Best fitness: 225.69452572688732
# 	Evaluations of fitness: 2649550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 44.05 s
# 	CPU time Spent:  44.05 s
# 	Generation: 11104
# 	Best fitness: 206.7975949054876
# 	Evaluations of fitness: 2776050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 46.05 s
# 	CPU time Spent:  46.05 s
# 	Generation: 11609
# 	Best fitness: 188.93881772570282
# 	Evaluations of fitness: 2902300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 48.05 s
# 	CPU time Spent:  48.05 s
# 	Generation: 12117
# 	Best fitness: 171.509257765813
# 	Evaluations of fitness: 3029300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 50.05 s
# 	CPU time Spent:  50.05 s
# 	Generation: 12625
# 	Best fitness: 155.08100044279126
# 	Evaluations of fitness: 3156300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 52.06 s
# 	CPU time Spent:  52.06 s
# 	Generation: 13133
# 	Best fitness: 139.62347012717782
# 	Evaluations of fitness: 3283300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 54.06 s
# 	CPU time Spent:  54.06 s
# 	Generation: 13639
# 	Best fitness: 124.8775675017356
# 	Evaluations of fitness: 3409800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 56.06 s
# 	CPU time Spent:  56.06 s
# 	Generation: 14142
# 	Best fitness: 111.02890561710872
# 	Evaluations of fitness: 3535550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 58.06 s
# 	CPU time Spent:  58.06 s
# 	Generation: 14653
# 	Best fitness: 97.70928056215621
# 	Evaluations of fitness: 3663300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 60.06 s
# 	CPU time Spent:  60.06 s
# 	Generation: 15158
# 	Best fitness: 85.73738114196298
# 	Evaluations of fitness: 3789550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 62.07 s
# 	CPU time Spent:  62.07 s
# 	Generation: 15667
# 	Best fitness: 74.10362656321183
# 	Evaluations of fitness: 3916800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 64.07 s
# 	CPU time Spent:  64.07 s
# 	Generation: 16170
# 	Best fitness: 63.726247760062726
# 	Evaluations of fitness: 4042550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 66.07 s
# 	CPU time Spent:  66.07 s
# 	Generation: 16673
# 	Best fitness: 54.060017089578636
# 	Evaluations of fitness: 4168300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 68.07 s
# 	CPU time Spent:  68.07 s
# 	Generation: 17177
# 	Best fitness: 45.178716924308034
# 	Evaluations of fitness: 4294300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 70.07 s
# 	CPU time Spent:  70.07 s
# 	Generation: 17674
# 	Best fitness: 37.18224511371686
# 	Evaluations of fitness: 4418550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 72.07 s
# 	CPU time Spent:  72.07 s
# 	Generation: 18172
# 	Best fitness: 30.040233636180304
# 	Evaluations of fitness: 4543050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 74.08 s
# 	CPU time Spent:  74.08 s
# 	Generation: 18675
# 	Best fitness: 23.618577698506897
# 	Evaluations of fitness: 4668800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 76.08 s
# 	CPU time Spent:  76.08 s
# 	Generation: 19185
# 	Best fitness: 17.976970588552454
# 	Evaluations of fitness: 4796300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 78.08 s
# 	CPU time Spent:  78.08 s
# 	Generation: 19692
# 	Best fitness: 13.02048026349722
# 	Evaluations of fitness: 4923050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 80.08 s
# 	CPU time Spent:  80.08 s
# 	Generation: 20199
# 	Best fitness: 8.953295422389875
# 	Evaluations of fitness: 5049800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 82.08 s
# 	CPU time Spent:  82.08 s
# 	Generation: 20696
# 	Best fitness: 5.735039402217986
# 	Evaluations of fitness: 5174050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 84.09 s
# 	CPU time Spent:  84.09 s
# 	Generation: 21207
# 	Best fitness: 3.21768553819039
# 	Evaluations of fitness: 5301800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 86.09 s
# 	CPU time Spent:  86.09 s
# 	Generation: 21714
# 	Best fitness: 1.455962657599028
# 	Evaluations of fitness: 5428550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 88.09 s
# 	CPU time Spent:  88.09 s
# 	Generation: 22222
# 	Best fitness: 0.3900994955388459
# 	Evaluations of fitness: 5555550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 90.09 s
# 	CPU time Spent:  90.09 s
# 	Generation: 22729
# 	Best fitness: 0.00208253750865607
# 	Evaluations of fitness: 5682300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 92.09 s
# 	CPU time Spent:  92.09 s
# 	Generation: 23234
# 	Best fitness: 8.532217074447804e-14
# 	Evaluations of fitness: 5808550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 94.1 s
# 	CPU time Spent:  94.1 s
# 	Generation: 23740
# 	Best fitness: 3.4477135374739506e-14
# 	Evaluations of fitness: 5935050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 96.1 s
# 	CPU time Spent:  96.1 s
# 	Generation: 24250
# 	Best fitness: 1.14327148719286e-14
# 	Evaluations of fitness: 6062550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 98.1 s
# 	CPU time Spent:  98.1 s
# 	Generation: 24760
# 	Best fitness: 7.63675562915794e-15
# 	Evaluations of fitness: 6190050

# %%
print(f"Best solution: {best_solution}")
print(f"Solution fitness: {best_fitness}")
# Out:
# Best solution: [9.88233434e-09 6.40053105e-09 8.65917334e-08]
# Solution fitness: 7.63675562915794e-15

# %%
search.display_report()
# Out:
# Number of generations: 25238
# Real time spent: 100.00237s
# CPU time spent: 99.92714s
# Number of fitness evaluations: 6309550
# Best fitness: 7.63675562915794e-15
