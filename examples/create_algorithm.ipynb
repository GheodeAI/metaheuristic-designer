# %% [markdown]
# # Creating an algorithm

# %% [markdown]
# In this notebook, we are going to explain how to implement a new optimization algorithm using the metaheuristic-designer framework.
#
# For this example, we are going to implement a basic evolutionary strategy.

# %%
import random
import metaheuristic_designer as mhd
from metaheuristic_designer import GeneralSearch
from metaheuristic_designer.SelectionMethods import SurvivorSelection, ParentSelection
from metaheuristic_designer.Operators import OperatorReal
from metaheuristic_designer.Initializers import UniformVectorInitializer
from metaheuristic_designer.benchmarks import Sphere

# %% [markdown]
# For simplicity, we will assume we are working with real coded vectors.
#
# We will also predefine the operators, but in real situations it might be wiser to let the user specify the user they want to use.
#
# To configure our evolution strategy, we will need to specify the number of parents and offpring in each generation.
# The operator will be a gaussian mutation, it will have a standard deviation associated which will be another parameter.
#
# To create the algorithm, we will make a class that inherits from ```Algorithm``` and will implement its methods.
#
# In this case we will implement the ```select_parents``` method that chooses the individuals to be chosen for mutation, the ```perturb``` method that will perform a mutation on the selected indivuals, the ```select_individuals``` that will choose the individuals that will remain for the next generation.
#
# Here, we will make extensive use of already implemented components, like ```ParentSelection```, ```SurvivorSelection```, ```Operator```, but you can provide your own implementation of those, which will be explained in different notebooks.

# %% [markdown]
# The ```Algorithm``` class has some attributes that must be used for the
# algorithm to work correctly.
#
# The algorithm will have a ```name```, if unspecified, a default name will be chosen. This is the name of the algorithm showed in logs.
#
# A population initialization module ```pop_init``` must be present to perform the initialization of the algorithm (an explanation will be present in its respective notebook). It will also specify the size of the initialized population.
#
# The algorithm has a list of individuals called ```population``` which holds. It is a standard python list with variable size.
#
# We also have a ```best``` attribute that holds the best individual in each generation.
#
# You can optionally store the parameters of the algorithm in a dictionary or an instance of ```ParamScheduler``` in the attribute ```params```. It is recomended to use the latter because it allows parameters to change over time. We will not worry about this in this example.
#
# All of these attributes are generated on the ```__init__``` method of the ```Algorithm``` class.

# %%
# ES algorithm class
class BasicES(mhd.Algorithm):

    # Class constructor
    def __init__(self, pop_init, parent_size, offspring_size, sigma):
        self.parent_size = parent_size
        self.offspring_size = offspring_size

        # Create the mutation operator for use later
        self.mutate_op = OperatorReal("MutRand", {"method": "Gauss", "F": sigma, "N": 1})

        # Force pop_init to agree with the population size, this is not mandatory.
        pop_init.pop_size = parent_size

        # Create the parent selection module, select the best half of the parents
        self.parent_sel_op = ParentSelection("Best", {"amount": parent_size//2})

        # Create the parent selection module, select the best half of the parents
        self.surv_sel_op = SurvivorSelection("keepbest", {"amount": parent_size})

        super().__init__(pop_init, name="Basic ES")
    
    
    # This method receives the population from the previous generation
    # and some extra information (that we don't need here) and returns 
    # a list of selected individuals.
    def select_parents(self, population, **kwargs):
        return self.parent_sel_op(population)
    

    # This method receives the parents that we are going to mutate,
    # the objective function class and some extra information that we 
    # are not going to use.
    def perturb(self, parent_list, objfunc, **kwargs):
        offspring = []

        # Iterate until the list of individuals has the 
        # size we want.
        while len(offspring) < self.offspring_size:

            # Choose an individual from the parent list.
            indiv = random.choice(parent_list)

            # Apply the operator.
            new_indiv = self.mutate_op(indiv, parent_list, objfunc, self.best, self.pop_init)

            # Repair the solution to keep the vector within the bounds
            # of the problem.
            new_indiv.genotype = objfunc.repair_solution(new_indiv.genotype)

            # Add the individual to the offspring list.
            offspring.append(new_indiv)
        
        # Update the best solution
        current_best = max(offspring, key=lambda x: x.fitness)
        if self.best.fitness < current_best.fitness:
            self.best = current_best
        
        return offspring


    # This method selects the individuals that will be chosen for the next 
    # generation, it gets the original population along with the newly 
    # generated individuals.
    def select_individuals(self, prev_population, offspring, **kwargs):
        return self.surv_sel_op(prev_population, offspring)

# %% [markdown]
# To begin with the optimization we need one more component, the ```SearchMethod```. This is mostly the same for all algorithms, so it is recomended that you use the already implemented ```GeneralSearch``` class for this purpose unless you REALLY need something different. If this is the case, you have a ```Search``` base class available that you can inherit from.
#
# We will be using one of the benchmark functions already implemented in this framework that consist on adding the square of the vector components.

# %%
# Define the parameters of the optimization process
params = {
    "stop_cond": "time_limit",
    "time_limit": 100.0,

    "verbose": True,
    "v_timer": 2
}

# Define the parameters of the algorithm
n_parents = 50
n_offspring = 250

# Define the objective function
objfunc = Sphere(3)

# Define a population initialization module
pop_init = UniformVectorInitializer(objfunc.vecsize, objfunc.low_lim, objfunc.up_lim, pop_size=n_parents)

# Instanciate the newly created algorithm
algorithm = BasicES(pop_init, n_parents, n_offspring, 1e-3)

# Define a Search method
search = GeneralSearch(objfunc, algorithm, params)

# Optimize the objective function 
best_solution, best_fitness = search.optimize()
# Out:
# Initializing optimization of Sphere function using Basic ES
# -----------------------------------------------------------
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 0.0 s
# 	CPU time Spent:  0.0 s
# 	Generation: 0
# 	Best fitness: 737.0390136666333
# 	Evaluations of fitness: 50
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 2.0 s
# 	CPU time Spent:  2.0 s
# 	Generation: 514
# 	Best fitness: 699.5789075480053
# 	Evaluations of fitness: 128550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 4.0 s
# 	CPU time Spent:  4.0 s
# 	Generation: 1030
# 	Best fitness: 662.9371170354655
# 	Evaluations of fitness: 257550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 6.01 s
# 	CPU time Spent:  6.01 s
# 	Generation: 1549
# 	Best fitness: 627.2927450099232
# 	Evaluations of fitness: 387300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 8.01 s
# 	CPU time Spent:  8.01 s
# 	Generation: 2061
# 	Best fitness: 592.3160474303784
# 	Evaluations of fitness: 515300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 10.01 s
# 	CPU time Spent:  10.01 s
# 	Generation: 2573
# 	Best fitness: 558.5830849488116
# 	Evaluations of fitness: 643300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 12.01 s
# 	CPU time Spent:  12.01 s
# 	Generation: 3087
# 	Best fitness: 526.0871459974062
# 	Evaluations of fitness: 771800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 14.01 s
# 	CPU time Spent:  14.01 s
# 	Generation: 3602
# 	Best fitness: 494.59130939126703
# 	Evaluations of fitness: 900550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 16.01 s
# 	CPU time Spent:  16.01 s
# 	Generation: 4110
# 	Best fitness: 464.8035391576787
# 	Evaluations of fitness: 1027550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 18.01 s
# 	CPU time Spent:  18.01 s
# 	Generation: 4620
# 	Best fitness: 435.6374298570664
# 	Evaluations of fitness: 1155050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 20.01 s
# 	CPU time Spent:  20.01 s
# 	Generation: 5132
# 	Best fitness: 407.80399852445544
# 	Evaluations of fitness: 1283050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 22.02 s
# 	CPU time Spent:  22.02 s
# 	Generation: 5653
# 	Best fitness: 380.40446303702345
# 	Evaluations of fitness: 1413300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 24.02 s
# 	CPU time Spent:  24.02 s
# 	Generation: 6172
# 	Best fitness: 353.72791125683943
# 	Evaluations of fitness: 1543050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 26.02 s
# 	CPU time Spent:  26.02 s
# 	Generation: 6692
# 	Best fitness: 328.0811047796307
# 	Evaluations of fitness: 1673050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 28.02 s
# 	CPU time Spent:  28.02 s
# 	Generation: 7205
# 	Best fitness: 304.3921580071862
# 	Evaluations of fitness: 1801300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 30.03 s
# 	CPU time Spent:  30.03 s
# 	Generation: 7721
# 	Best fitness: 281.25885449193095
# 	Evaluations of fitness: 1930300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 32.03 s
# 	CPU time Spent:  32.03 s
# 	Generation: 8234
# 	Best fitness: 259.7298351115846
# 	Evaluations of fitness: 2058550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 34.03 s
# 	CPU time Spent:  34.03 s
# 	Generation: 8746
# 	Best fitness: 239.00088332634405
# 	Evaluations of fitness: 2186550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 36.03 s
# 	CPU time Spent:  36.03 s
# 	Generation: 9258
# 	Best fitness: 218.99713421577871
# 	Evaluations of fitness: 2314550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 38.04 s
# 	CPU time Spent:  38.04 s
# 	Generation: 9778
# 	Best fitness: 199.80068796725476
# 	Evaluations of fitness: 2444550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 40.04 s
# 	CPU time Spent:  40.04 s
# 	Generation: 10293
# 	Best fitness: 181.6309915173536
# 	Evaluations of fitness: 2573300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 42.04 s
# 	CPU time Spent:  42.04 s
# 	Generation: 10809
# 	Best fitness: 164.08421514602682
# 	Evaluations of fitness: 2702300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 44.04 s
# 	CPU time Spent:  44.04 s
# 	Generation: 11313
# 	Best fitness: 147.91811546672668
# 	Evaluations of fitness: 2828300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 46.04 s
# 	CPU time Spent:  46.04 s
# 	Generation: 11818
# 	Best fitness: 132.56821628686183
# 	Evaluations of fitness: 2954550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 48.05 s
# 	CPU time Spent:  48.05 s
# 	Generation: 12337
# 	Best fitness: 117.71650612736435
# 	Evaluations of fitness: 3084300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 50.05 s
# 	CPU time Spent:  50.05 s
# 	Generation: 12855
# 	Best fitness: 103.98582427001382
# 	Evaluations of fitness: 3213800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 52.05 s
# 	CPU time Spent:  52.05 s
# 	Generation: 13378
# 	Best fitness: 90.79601198931798
# 	Evaluations of fitness: 3344550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 54.05 s
# 	CPU time Spent:  54.05 s
# 	Generation: 13900
# 	Best fitness: 78.7454471211087
# 	Evaluations of fitness: 3475050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 56.06 s
# 	CPU time Spent:  56.06 s
# 	Generation: 14420
# 	Best fitness: 67.58976209265822
# 	Evaluations of fitness: 3605050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 58.06 s
# 	CPU time Spent:  58.06 s
# 	Generation: 14942
# 	Best fitness: 57.31026843491827
# 	Evaluations of fitness: 3735550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 60.06 s
# 	CPU time Spent:  60.06 s
# 	Generation: 15462
# 	Best fitness: 47.97597932283011
# 	Evaluations of fitness: 3865550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 62.06 s
# 	CPU time Spent:  62.06 s
# 	Generation: 15983
# 	Best fitness: 39.24100168219245
# 	Evaluations of fitness: 3995800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 64.06 s
# 	CPU time Spent:  64.06 s
# 	Generation: 16500
# 	Best fitness: 31.606412001988424
# 	Evaluations of fitness: 4125050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 66.06 s
# 	CPU time Spent:  66.06 s
# 	Generation: 17018
# 	Best fitness: 24.805459663731824
# 	Evaluations of fitness: 4254550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 68.06 s
# 	CPU time Spent:  68.06 s
# 	Generation: 17539
# 	Best fitness: 18.803707478239097
# 	Evaluations of fitness: 4384800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 70.06 s
# 	CPU time Spent:  70.06 s
# 	Generation: 18059
# 	Best fitness: 13.697424997163084
# 	Evaluations of fitness: 4514800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 72.07 s
# 	CPU time Spent:  72.07 s
# 	Generation: 18578
# 	Best fitness: 9.445003605138448
# 	Evaluations of fitness: 4644550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 74.07 s
# 	CPU time Spent:  74.07 s
# 	Generation: 19099
# 	Best fitness: 6.022583365530254
# 	Evaluations of fitness: 4774800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 76.07 s
# 	CPU time Spent:  76.07 s
# 	Generation: 19620
# 	Best fitness: 3.380762159997992
# 	Evaluations of fitness: 4905050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 78.07 s
# 	CPU time Spent:  78.07 s
# 	Generation: 20139
# 	Best fitness: 1.5424458242030814
# 	Evaluations of fitness: 5034800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 80.07 s
# 	CPU time Spent:  80.07 s
# 	Generation: 20658
# 	Best fitness: 0.422249471507756
# 	Evaluations of fitness: 5164550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 82.07 s
# 	CPU time Spent:  82.07 s
# 	Generation: 21178
# 	Best fitness: 0.002958821667861171
# 	Evaluations of fitness: 5294550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 84.08 s
# 	CPU time Spent:  84.08 s
# 	Generation: 21704
# 	Best fitness: 3.064361249086805e-14
# 	Evaluations of fitness: 5426050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 86.08 s
# 	CPU time Spent:  86.08 s
# 	Generation: 22227
# 	Best fitness: 1.0418641792290511e-14
# 	Evaluations of fitness: 5556800
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 88.08 s
# 	CPU time Spent:  88.08 s
# 	Generation: 22749
# 	Best fitness: 1.0418641792290511e-14
# 	Evaluations of fitness: 5687300
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 90.08 s
# 	CPU time Spent:  90.08 s
# 	Generation: 23270
# 	Best fitness: 9.261541047433017e-15
# 	Evaluations of fitness: 5817550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 92.09 s
# 	CPU time Spent:  92.09 s
# 	Generation: 23792
# 	Best fitness: 9.261541047433017e-15
# 	Evaluations of fitness: 5948050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 94.09 s
# 	CPU time Spent:  94.09 s
# 	Generation: 24312
# 	Best fitness: 8.242636644270565e-15
# 	Evaluations of fitness: 6078050
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 96.09 s
# 	CPU time Spent:  96.09 s
# 	Generation: 24838
# 	Best fitness: 8.242636644270565e-15
# 	Evaluations of fitness: 6209550
#
# Optimizing Sphere function using Basic ES:
# 	Real time Spent: 98.09 s
# 	CPU time Spent:  98.09 s
# 	Generation: 25361
# 	Best fitness: 4.826737087011489e-15
# 	Evaluations of fitness: 6340300

# %%
print(f"Best solution: {best_solution}")
print(f"Solution fitness: {best_fitness}\n")
search.display_report()
# Out:
# Best solution: [-3.52755789e-09  8.92106839e-09 -2.75844894e-08]
# Solution fitness: 8.529331816261457e-16
#
# Number of generations: 25859
# Real time spent: 100.00313s
# CPU time spent: 99.92963s
# Number of fitness evaluations: 6464800
# Best fitness: 8.529331816261457e-16

# %%
# Out:
# Number of generations: 25859
# Real time spent: 100.00313s
# CPU time spent: 99.92963s
# Number of fitness evaluations: 6464800
# Best fitness: 8.529331816261457e-16
